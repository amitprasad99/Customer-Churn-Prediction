# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churn = pd.read_csv(r"C:\Users\amitp\OneDrive\Documents\Projects_3rd Year\CodSoft\Customer Churn Prediction\archive (4)\Churn_Modelling.csv")
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churn.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
churn.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn['Exited'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
for i in churn.columns:
    print(i,'\n',churn[i].unique())
# Out:
# RowNumber
#  [    1     2     3 ...  9998  9999 10000]
# CustomerId
#  [15634602 15647311 15619304 ... 15584532 15682355 15628319]
# Surname
#  ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
# CreditScore
#  [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
# ...

# %%
churn.Exited.count()
# Out:
# 10000

# %%
churn.drop('Surname',axis=1,inplace=True)

# %%
churn.head()
# Out:
#    RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602          619    France  Female   42       2
# 1          2    15647311          608     Spain  Female   41       1
# 2          3    15619304          502    France  Female   42       8
# 3          4    15701354          699    France  Female   39       1
# 4          5    15737888          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
sns.countplot(x=churn.Exited)
plt.show()

# %%
sns.barplot(x=churn.Exited,y=churn.Balance)
plt.show()

# %%
sns.boxplot(x=churn.Exited,y=churn.Balance)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
churn.Geography=le.fit_transform(churn.Geography)
churn.Gender=le.fit_transform(churn.Gender)

# %%
churn.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602          619          0       0   42       2
# 1          2    15647311          608          2       0   41       1
# 2          3    15619304          502          0       0   42       8
# 3          4    15701354          699          0       0   39       1
# 4          5    15737888          850          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
sns.distplot(x=churn.Balance[churn.Exited==0])
plt.show()
# Out:
# C:\Users\amitp\AppData\Local\Temp\ipykernel_7172\2458649436.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=churn.Balance[churn.Exited==0])

# %%
sns.displot(x=churn.Balance[churn.Exited==0])
plt.show()
# Out:
# C:\Users\amitp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ip=churn.drop('Exited',axis=1)
op=churn.Exited

# %%
ip
# Out:
#       RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0             1    15634602          619          0       0   42       2
# 1             2    15647311          608          2       0   41       1
# 2             3    15619304          502          0       0   42       8
# 3             4    15701354          699          0       0   39       1
# 4             5    15737888          850          2       0   43       2
# ...         ...         ...          ...        ...     ...  ...     ...
# 9995       9996    15606229          771          0       1   39       5
# 9996       9997    15569892          516          0       1   35      10
# 9997       9998    15584532          709          0       0   36       7
# 9998       9999    15682355          772          1       1   42       3
# 9999      10000    15628319          792          0       0   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
op
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtr,xt,ytr,yt=train_test_split(ip,op,train_size=0.8)

# %%
xtr
# Out:
#       RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 7975       7976    15794356          641          1       1   42       3
# 5104       5105    15694349          714          2       1   44       7
# 4498       4499    15777759          570          0       1   30       2
# 1524       1525    15653595          796          0       1   51       6
# 9655       9656    15668971          583          0       0   40       4
# ...         ...         ...          ...        ...     ...  ...     ...
# 6366       6367    15677324          683          1       1   73       9
# 2697       2698    15699450          723          0       1   48       7
# 8244       8245    15656330          528          2       0   32       0
# 5103       5104    15808526          783          1       0   58       3
# 895         896    15697000          728          1       1   32       5
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtr=sc.fit_transform(xtr)
xt=sc.fit_transform(xt)

# %%
xtr
# Out:
# array([[ 1.02574026,  1.4359638 , -0.10444511, ...,  0.6493972 ,
#          0.9614909 ,  1.15351411],
#        [ 0.03413129,  0.04351617,  0.65513674, ..., -1.53988961,
#          0.9614909 , -1.61526683],
#        [-0.17517385,  1.20487544, -0.84321649, ...,  0.6493972 ,
#          0.9614909 , -0.90345156],
#        ...,
#        [ 1.11864964, -0.48584144, -1.28023619, ...,  0.6493972 ,
#          0.9614909 ,  1.21930733],
#        [ 0.0337859 ,  1.63325982,  1.37309767, ...,  0.6493972 ,
#          0.9614909 , -0.05963519],
#        [-1.41960685,  0.08042737,  0.80080997, ...,  0.6493972 ,
#          0.9614909 ,  0.97322556]])

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(xtr,ytr)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(xt)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score
acc=accuracy_score(y_pred,yt)
rec=recall_score(y_pred,yt,average='macro')
pre=precision_score(y_pred,yt,average='macro')
f1=f1_score(y_pred,yt,average='macro')

print(acc,rec,pre,f1)
# Out:
# 0.813 0.7120331522112937 0.57735933098702 0.5879959196173429

# %%
#GNB
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(xtr,ytr)
# Out:
# GaussianNB()

# %%
g_pred=gnb.predict(xt)
g_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score
acc=accuracy_score(g_pred,yt)
rec=recall_score(g_pred,yt,average='macro')
pre=precision_score(g_pred,yt,average='macro')
f1=f1_score(g_pred,yt,average='macro')

print(acc,rec,pre,f1)
# Out:
# 0.8335 0.7756410034871142 0.6250901824980082 0.6516690856313498

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(xtr,ytr)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
k_pred=knn.predict(xt)
k_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score
acc=accuracy_score(k_pred,yt)
rec=recall_score(k_pred,yt,average='macro')
pre=precision_score(k_pred,yt,average='macro')
f1=f1_score(k_pred,yt,average='macro')

print(acc,rec,pre,f1)
# Out:
# 0.8315 0.7413012934652515 0.6672736340880432 0.6908539082900229

# %%
from sklearn.svm import SVC  #SVC-->Support Vector Classifier
svc=SVC(kernel='rbf',C=10000,gamma=0.01)  #C=Regularization Parameter
svc.fit(xtr,ytr)
# Out:
# SVC(C=10000, gamma=0.01)

# %%
s_pred=svc.predict(xt)
s_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score
acc=accuracy_score(s_pred,yt)
rec=recall_score(s_pred,yt,average='macro')
pre=precision_score(s_pred,yt,average='macro')
f1=f1_score(s_pred,yt,average='macro')

print(acc,rec,pre,f1)
# Out:
# 0.8645 0.8102596646758541 0.726583918343277 0.7561975088063531
